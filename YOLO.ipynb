# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt') # default
# Out:
# ...
# 100%|██████████| 6.51M/6.51M [00:01<00:00, 3.57MB/s]

# %%
results = model(source=0, show=True, save=True, conf=0.4) # webcam
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 1 person, 26.2ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# 0: 480x640 1 person, 44.7ms
# WARNING ⚠️ Waiting for stream 0
# 0: 480x640 1 person, 24.8ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# 0: 480x640 1 person, 24.3ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# ...

# %%
modelPose = YOLO('yolov8n-pose.pt')

# %%
resultsPose = modelPose(source=0, show=True, save=True, conf=0.4) # webcam
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 2 persons, 23.9ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# 0: 480x640 1 person, 24.4ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# 0: 480x640 2 persons, 21.5ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# 0: 480x640 1 person, 23.6ms
# WARNING ⚠️ Waiting for stream 0
# ...
